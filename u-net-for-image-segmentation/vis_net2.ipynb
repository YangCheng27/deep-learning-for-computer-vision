# %%
import unet
import matplotlib.pyplot as plt
import kagglehub

path = kagglehub.dataset_download("maedemaftouni/covid19-ct-scan-lesion-segmentation-dataset")
loaders = unet.get_dataloaders(path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.4)

# %%
unet.data_vis(loaders['evaluation'])

# %%
model = unet.SimpleUNet2()

# %%
train_losses, val_losses, epoch_times, train_metrics_history, val_metrics_history = unet.train_model(
    model, loaders['training'], loaders['evaluation'], num_epochs=9, device=unet.get_device()
)
# Out:
# Use mps for GPU training acceleration.
#
# Start to train using: mps
# Training Epochs:  11%|█         | 1/9 [04:01<32:13, 241.64s/it]
# Epoch 1/9
# Train Loss: 0.6775
# Val Loss: 0.6636
# Epoch Time: 241.64s
#
# Training Metrics:
# Dice Score: 0.1072
# IoU: 0.0621
#
# Validation Metrics:
# Dice Score: 0.0896
# IoU: 0.0602
# Training Epochs:  22%|██▏       | 2/9 [08:04<28:14, 242.11s/it]
# Epoch 2/9
# Train Loss: 0.5843
# Val Loss: 0.6569
# Epoch Time: 242.42s
#
# Training Metrics:
# Dice Score: 0.2264
# IoU: 0.1381
#
# Validation Metrics:
# Dice Score: 0.1018
# IoU: 0.0715
# Epoch 3/9
# Train Loss: 0.5659
# Val Loss: 0.6425
# Epoch Time: 385.22s
#
# Training Metrics:
# Dice Score: 0.2476
# IoU: 0.1528
#
# Validation Metrics:
# Dice Score: 0.1214
# IoU: 0.0859
# Training Epochs:  44%|████▍     | 4/9 [18:38<23:37, 283.52s/it]
# Epoch 4/9
# Train Loss: 0.5548
# Val Loss: 0.6489
# Epoch Time: 241.22s
#
# Training Metrics:
# Dice Score: 0.2609
# IoU: 0.1635
#
# Validation Metrics:
# Dice Score: 0.1031
# IoU: 0.0710
# Training Epochs:  56%|█████▌    | 5/9 [22:40<17:54, 268.54s/it]
# Epoch 5/9
# Train Loss: 0.5403
# Val Loss: 0.5547
# Epoch Time: 241.96s
#
# Training Metrics:
# Dice Score: 0.2852
# IoU: 0.1785
#
# Validation Metrics:
# Dice Score: 0.2286
# IoU: 0.1489
# Epoch 6/9
# Train Loss: 0.5089
# Val Loss: 0.4366
# Epoch Time: 239.57s
#
# Training Metrics:
# Dice Score: 0.3309
# IoU: 0.2093
#
# Validation Metrics:
# Dice Score: 0.4247
# IoU: 0.3093
# Training Epochs:  78%|███████▊  | 7/9 [30:49<08:29, 254.88s/it]
# Epoch 7/9
# Train Loss: 0.4737
# Val Loss: 0.5069
# Epoch Time: 241.14s
#
# Training Metrics:
# Dice Score: 0.3773
# IoU: 0.2420
#
# Validation Metrics:
# Dice Score: 0.3050
# IoU: 0.2080
# Training Epochs:  89%|████████▉ | 8/9 [34:52<04:11, 251.09s/it]
# Epoch 8/9
# Train Loss: 0.4439
# Val Loss: 0.4395
# Epoch Time: 242.97s
#
# Training Metrics:
# Dice Score: 0.4176
# IoU: 0.2743
#
# Validation Metrics:
# Dice Score: 0.3990
# IoU: 0.2989
# Epoch 9/9
# Train Loss: 0.4236
# Val Loss: 0.4047
# Epoch Time: 243.78s
#
# Training Metrics:
# Dice Score: 0.4439
# IoU: 0.2956
#
# Validation Metrics:
# Dice Score: 0.4514
# IoU: 0.3369
# Training Epochs: 100%|██████████| 9/9 [39:10<00:00, 261.11s/it]

# %%
unet.plot_result(train_losses, val_losses, train_metrics_history, val_metrics_history)
